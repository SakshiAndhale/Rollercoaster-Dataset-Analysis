# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
import warnings
warnings.filterwarnings('ignore', category=FutureWarning, module='seaborn')

# %%
# import csv file
df = pd.read_csv('coaster_db.csv', encoding= 'unicode_escape')

# %%
#DATA UNDERSTANDING
df.shape
#This tells us the shape of the data frame that we just loaded. That is it gives us the number of rows and columns present in the dataset.
# Out:
# (1087, 56)

# %%
df.head(10)
# Out:
#                              coaster_name              Length  \
# 0                      Switchback Railway    600Â ft (180Â m)
# 1                       Flip Flap Railway                 NaN
# 2  Switchback Railway (Euclid Beach Park)                 NaN
# 3            Loop the Loop (Coney Island)                 NaN
# 4            Loop the Loop (Young's Pier)                 NaN
# 5                          Cannon Coaster                 NaN
# 6                           Leap-The-Dips  1,452Â ft (443Â m)
# 7        Figure Eight (Euclid Beach Park)                 NaN
# 8                            Drop the Dip                 NaN
# 9      Scenic Railway (Euclid Beach Park)                 NaN
#
#               Speed                        Location     Status  \
# 0  6 mph (9.7 km/h)                    Coney Island    Removed
# 1               NaN                   Sea Lion Park    Removed
# 2               NaN  Cleveland, Ohio, United States     Closed
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
#DATA PREPARATION

#Drop irrelevant columns and rows
#Identifying duplicate coulmns
#Renaming columns
#Feature Creation

# %%
#If you want to drop a single coulmn use:
# df.drop(['Column name'], axis = 1)

# To drop multiple columns at once use by using subsets:

df = df[['coaster_name',
    #'Length', 'Speed',
    'Location', 'Status',
    #'Opening date',
    #   'Type', 
    'Manufacturer', 
    #'Height restriction', 'Model', 'Height',  'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section','Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
    #   'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
     #  'Track layout', 'Fastrack available', 'Soft opening date.1',
      # 'Closing date', 
  #  'Opened', 
    #'Replaced by', 'Website',
  #     'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
   #  'Single rider line available', 'Restraint Style',
   #'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced',
    'latitude', 'longitude', 
    'Type_Main',
       'opening_date_clean',
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #'height_value', 'height_unit', 
    'height_ft',
       'Inversions_clean', 'Gforce_clean',]].copy()

# %%
df.shape
# Out:
# (1087, 13)

# %%
df.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Manufacturer           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %%
df.dtypes
# Out:
# coaster_name                  object
# Location                      object
# Status                        object
# Manufacturer                  object
# year_introduced                int64
# latitude                     float64
# longitude                    float64
# Type_Main                     object
# opening_date_clean    datetime64[ns]
# speed_mph                    float64
# height_ft                    float64
# Inversions_clean               int64
# Gforce_clean                 float64
# dtype: object

# %%
df['year_introduced'] = pd.to_numeric(df['year_introduced'])

# %%
#How to rename our columns
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df = df.rename(columns = {'coaster_name':'Coaster Name','year_introduced':'Year Introduced', 'latitude':'Latitude', 'longitude':'Longitude', 'Type_Main':'Type Main', 'opening_date_clean': 'Opening Date', 'speed_mph':'Speed in mph','height_ft':'Height in ft', 'Inversions_clean':'Inversions','Gforce_clean':'Gforce'})

# %%
df.head()
# Out:
#                              Coaster Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year Introduced  Latitude  Longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type Main Opening Date  Speed in mph  Height in ft  Inversions  Gforce
# ...

# %%
df.isna()
# Out:
#       Coaster Name  Location  Status  Manufacturer  Year Introduced  Latitude  \
# 0            False     False   False         False            False     False
# 1            False     False   False         False            False     False
# 2            False     False   False          True            False     False
# 3            False     False   False         False            False     False
# 4            False     False   False         False            False     False
# ...            ...       ...     ...           ...              ...       ...
# 1082         False     False    True         False            False      True
# 1083         False     False   False         False            False     False
# 1084         False     False    True         False            False      True
# 1085         False     False   False         False            False      True
# 1086         False     False   False         False            False      True
#
# ...

# %%
df.isna().sum()
# Out:
# Coaster Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year Introduced      0
# Latitude           275
# Longitude          275
# Type Main            0
# Opening Date       250
# Speed in mph       150
# Height in ft       916
# Inversions           0
# Gforce             725
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster Name, Location, Status, Manufacturer, Year Introduced, Latitude, Longitude, Type Main, Opening Date, Speed in mph, Height in ft, Inversions, Gforce]
# Index: []

# %%
#you can check for duplicated rows through: {This will show the second duplicate, ie as the first appearance of the row is true and the second is automatically the duplicate
df.loc[df.duplicated(subset=['Coaster Name'])].head(5)
# Out:
#                           Coaster Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           Manufacturer  Year Introduced  \
# 43                                  Traver Engineering             1927
# 60                                      Fred W. Pearce             1937
# 61                                                 NaN             1938
# 167  Arrow Development (California and Florida)Dyna...             1980
# 237                                         Mack Rides             1986
#
#      Latitude  Longitude Type Main Opening Date  Speed in mph  Height in ft  \
# ...

# %%
# Checking for specific duplicates
df.query("`Coaster Name` == 'Crystal Beach Cyclone'")
# Out:
#              Coaster Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year Introduced  Latitude  Longitude Type Main Opening Date  Speed in mph  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01          60.0
# 43             1927   42.8617   -79.0598      Wood   1926-01-01          60.0
#
#     Height in ft  Inversions  Gforce
# 39           NaN           0     4.0
# 43           NaN           0     4.0

# %%
df.columns
# Out:
# Index(['Coaster Name', 'Location', 'Status', 'Manufacturer', 'Year Introduced',
#        'Latitude', 'Longitude', 'Type Main', 'Opening Date', 'Speed in mph',
#        'Height in ft', 'Inversions', 'Gforce'],
#       dtype='object')

# %%
df.duplicated(subset=['Coaster Name', 'Location', 'Opening Date']).sum()
# Out:
# 97

# %%
df.loc[~df.duplicated(subset=['Coaster Name', 'Location', 'Opening Date'])]
# Out:
#                                 Coaster Name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1079            Ice Breaker (roller coaster)                SeaWorld Orlando
# 1081                   Leviathan (Sea World)                       Sea World
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df = df.loc[~df.duplicated(subset=['Coaster Name', 'Location', 'Opening Date'])].reset_index(drop=True).copy()

# %%
df.shape
# Out:
# (990, 13)

# %%
#Feature Understanding / Univariant analysis

# %%
df['Year Introduced'].value_counts()
# Out:
# Year Introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: count, Length: 101, dtype: int64

# %%
    ax = df['Year Introduced'].value_counts()\
        .head(10)\
        .plot(kind='bar', title='Top Years 10 Rollercoasters Introduced')
ax.set_xlabel('Year Introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['Speed in mph'].plot(kind='hist', bins=20, title = 'Rollercoaster speed in mph')
ax.set_xlabel('Speed(mph)')
# Out:
# Text(0.5, 0, 'Speed(mph)')

# %%
#Here we use a KDE (Kernel Density Plot) for the speed of the rollercoasters.

ax = df['Speed in mph'].plot(kind='kde', title = 'Rollercoaster speed in mph')
ax.set_xlabel('Speed(mph)')
# Out:
# Text(0.5, 0, 'Speed(mph)')

# %%
#Feature Relationship graphs

df.head()
# Out:
#                              Coaster Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year Introduced  Latitude  Longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type Main Opening Date  Speed in mph  Height in ft  Inversions  Gforce
# ...

# %%
df.plot(kind='scatter', x='Speed in mph', y='Height in ft', title = 'Speed vs Height')
plt.show()

# %%
sns.scatterplot(x='Speed in mph', y='Height in ft', hue='Year Introduced', data= df)
# Out:
# <Axes: xlabel='Speed in mph', ylabel='Height in ft'>

# %%
sns.pairplot(df, vars=['Year Introduced', 'Speed in mph',	'Height in ft',	'Inversions',	'Gforce'])
plt.show()

# %%
sns.pairplot(df, vars=['Year Introduced', 'Speed in mph','Height in ft','Inversions',	'Gforce'], hue='Type Main')
plt.show()

# %%
df_corr= df[['Year Introduced', 'Speed in mph','Height in ft','Inversions',	'Gforce']].dropna().corr()
df_corr
# Out:
#                  Year Introduced  Speed in mph  Height in ft  Inversions  \
# Year Introduced         1.000000      0.171978      0.135413   -0.209887
# Speed in mph            0.171978      1.000000      0.733999   -0.028705
# Height in ft            0.135413      0.733999      1.000000   -0.079736
# Inversions             -0.209887     -0.028705     -0.079736    1.000000
# Gforce                  0.160247      0.607383      0.466482    0.275991
#
#                    Gforce
# Year Introduced  0.160247
# Speed in mph     0.607383
# Height in ft     0.466482
# Inversions       0.275991
# Gforce           1.000000

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
 df.head()
# Out:
#                              Coaster Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year Introduced  Latitude  Longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type Main Opening Date  Speed in mph  Height in ft  Inversions  Gforce
# ...

# %%
#Answering Questions
#What are the locations with the fastest rollercoasters

df['Location'].value_counts()
# Out:
# Location
# Other                            181
# Kings Island                      19
# Cedar Point                       18
# Six Flags Magic Mountain          17
# Hersheypark                       16
#                                 ...
# Granada Studios Tour               1
# Funtown Splashtown USA             1
# Tolchester Beach Park              1
# Suzuka, Mie Prefecture, Japan      1
# Epcot                              1
# Name: count, Length: 280, dtype: int64

# %%
df.query('Location != "Other"').groupby('Location')['Speed in mph'].agg(['mean', 'count']).query('count>=10').sort_values('mean')\
.plot(kind='barh',figsize=(12,5), title = 'Average Rollercoaster Speed by Location')

ax.set_xlabel('Average Rollercoaster Speed')
plt.show()
